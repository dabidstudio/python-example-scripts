# %% [markdown]
# <a href="https://colab.research.google.com/github/dabidstudio/python-example-scripts/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9C%BC%EB%A1%9C_3%EC%B4%88%EB%A7%8C%EC%97%90_%ED%91%9C%EB%A1%9C_%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C%EB%B0%9B%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

tables = pd.read_html("https://finance.naver.com/sise/sise_low_up.naver",encoding="euc-kr")

# 찾은 표의 수 확인
len(tables)
# Out:
# 2

# %%
tables[0]
# Out:
#      0      1          2        3          4       5
# 0  거래량   매수호가   거래대금(백만)  시가총액(억)    영업이익(억)  PER(배)
# 1   시가   매도호가      전일거래량  자산총계(억)    영업이익증가율  ROE(%)
# 2   고가  매수총잔량      외국인비율  부채총계(억)   당기순이익(억)  ROA(%)
# 3   저가  매도총잔량  상장주식수(천주)   매출액(억)   주당순이익(원)  PBR(배)
# 4  NaN    NaN        NaN   매출액증가율  보통주배당금(원)  유보율(%)

# %%
tables[1]
# Out:
#          N     등락률     종목명      현재가     전일비    등락률.1       시가       고가  \
# 0      NaN     NaN     NaN      NaN     NaN      NaN      NaN      NaN
# 1      1.0  29.96%  SK이터닉스  12840.0  2960.0  +29.96%   9880.0  12840.0
# 2      2.0  15.50%  SNT에너지  30550.0  5600.0  +22.44%  28500.0  32350.0
# 3      3.0  15.34%  롯데손해보험   3195.0   395.0  +14.11%   2795.0   3630.0
# 4      4.0  11.55%     디아이  12750.0  1430.0  +12.63%  11430.0  14030.0
# ..     ...     ...     ...      ...     ...      ...      ...      ...
# 156   99.0   2.96%      후성   8000.0    20.0   +0.25%   7980.0   8080.0
# 157  100.0   2.90%    대림통상   3020.0    25.0   +0.83%   2995.0   3045.0
# 158    NaN     NaN     NaN      NaN     NaN      NaN      NaN      NaN
# 159    NaN     NaN     NaN      NaN     NaN      NaN      NaN      NaN
# 160    NaN     NaN     NaN      NaN     NaN      NaN      NaN      NaN
#
#           저가         거래량     PER    ROE
# 0        NaN         NaN     NaN    NaN
# ...

# %%
cleaned_df = tables[1].dropna(subset=['종목명'])
cleaned_df
# Out:
#          N     등락률                      종목명       현재가     전일비    등락률.1  \
# 1      1.0  29.96%                   SK이터닉스   12840.0  2960.0  +29.96%
# 2      2.0  15.50%                   SNT에너지   30550.0  5600.0  +22.44%
# 3      3.0  15.34%                   롯데손해보험    3195.0   395.0  +14.11%
# 4      4.0  11.55%                      디아이   12750.0  1430.0  +12.63%
# 5      5.0  11.02%                    대호에이엘    1199.0   109.0  +10.00%
# ..     ...     ...                      ...       ...     ...      ...
# 153   96.0   3.05%                     하이트론    1216.0    52.0   -4.10%
# 154   97.0   3.04%                   SK하이닉스  183000.0  4800.0   +2.69%
# 155   98.0   2.99%  삼성 인버스 2X 코스닥150 선물 ETN    5340.0   115.0   +2.20%
# 156   99.0   2.96%                       후성    8000.0    20.0   +0.25%
# 157  100.0   2.90%                     대림통상    3020.0    25.0   +0.83%
#
#            시가        고가        저가         거래량     PER     ROE
# ...
